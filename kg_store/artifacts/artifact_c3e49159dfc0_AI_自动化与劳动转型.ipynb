# %% [markdown]
# # AI 自动化与劳动转型 学习笔记
#
# 本 Notebook 基于本地知识库资料自动生成，目标是把论文、课件和笔记整理成可快速复习、可继续实验的学习材料。
#
# ## 学习目标
#
# - 理解 `AI 自动化与劳动转型` 的核心问题、基本定义和典型应用场景。
# - 能够把资料中的关键概念整理成自己的知识结构。
# - 能够通过一个小型代码示例验证学习内容。
# - 重点关注：LLM、AI、GPT。
#
# ## 使用资料
#
# - literature_notes.md

# %% [markdown]
# ## 1. 学习路线
#
# 建议按以下顺序学习：
#
# 1. 先把 `AI 自动化与劳动转型` 的基本定义和问题背景读清楚。
# 2. 再理解关键概念之间的关系：LLM, AI, GPT。
# 3. 然后结合代码或小例子验证自己的理解。
# 4. 最后用练习题检查是否能迁移到新资料。

# %% [markdown]
# ## 2. LLM
#
# 这一节来自 `literature_notes.md`，适合用来理解 `AI 自动化与劳动转型` 中的 `LLM、AI`。阅读时不要只记住名词，要关注它解决什么问题、依赖哪些前置知识，以及它和其他方法的关系。
#
# **资料片段**
#
# > - 核心观点：约 80% 美国劳动者所在职业至少 10% 任务暴露于 LLM；约 19% 职业有一半以上任务暴露。但暴露度不是自动化结果，也不是采用时间表。 - 可用于本文：把 AI 影响从“岗位消失”转化为“任务暴露与工作流程变化”。 5. `2025_Pissarides_Review_Future_Work_Wellbeing.pdf` - 主要问题：自动化如何影响工作质量、技能、福祉和政策。 - 核心观点：仅靠任务替代预测不足以理解自动化；AI 会影响劳动者自主性、学习、参与、焦虑和福祉。报告主张以“好工作”和人本自动化作为治理目标。 - 可用于本文：补强自然辩证法中的“人的全面发展”和制度治理部分。

# %%
concepts = ['LLM', 'AI', 'GPT']

print("本节关键概念：")
for i, concept in enumerate(concepts, start=1):
    print(f"{i}. {concept}")

knowledge_map = {
    "topic": 'AI 自动化与劳动转型',
    "concepts": concepts,
    "review_prompt": "请用自己的话解释每个概念，并写出它和主题的关系。"
}

knowledge_map
# Out:
# Running cells with '.venv (Python 3.12.13)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/0_code/10_read/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %% [markdown]
# ## 3. LLM
#
# 这一节来自 `literature_notes.md`，适合用来理解 `AI 自动化与劳动转型` 中的 `LLM、GPT、AI`。阅读时不要只记住名词，要关注它解决什么问题、依赖哪些前置知识，以及它和其他方法的关系。
#
# **资料片段**
#
# > 1. `2013_Frey_Osborne_Future_of_Employment.pdf` - 主要问题：哪些职业在技术上更容易被计算机化。 - 核心观点：约 47% 的美国就业处于较高计算机化风险类别，但作者强调这是“潜在风险”而非实际失业预测。 - 可用于本文：作为“替代劳动”焦虑的代表性文献。 2. `2015_Autor_Why_Are_There_Still_So_Many_Jobs.pdf` - 主要问题：为什么自动化长期存在，但工作并未消失。 - 核心观点：工作由多种任务构成，自动化替代部分任务，也会提高剩余人类任务的价值；岗位结构会发生极化。 - 可用于本文：支持“AI 替代的是任务，不是整体劳动主体”。 3. `2019_Acemoglu_Restrepo_Automation_and_New_Tasks.pdf` - 主要问题：自动化如何同时排挤劳动并创造新任务。 - 核心观点：自动化产生 displac...

# %% [markdown]
# ## 练习
#
# 1. 用 3-5 句话解释 `AI 自动化与劳动转型` 的核心思想。
# 2. 解释 `LLM` 与 `AI 自动化与劳动转型` 的关系。
# 3. 从参考资料中找出一个关键概念，说明它的输入、输出和适用场景。

# %% [markdown]
# ## 参考来源
#
# - literature_notes.md
